# %%
# !pip install biopython matplotlib
# Out:
# Requirement already satisfied: biopython in c:\users\vhmoh\anaconda3\lib\site-packages (1.85)
# Requirement already satisfied: matplotlib in c:\users\vhmoh\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\vhmoh\anaconda3\lib\site-packages (from biopython) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vhmoh\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vhmoh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from Bio import Phylo , AlignIO
from Bio.Phylo.TreeConstruction import DistanceCalculator,DistanceTreeConstructor
import matplotlib.pyplot as plt

# %%
alignment=AlignIO.read("out.aln","clustal")
calculator=DistanceCalculator()
dm=calculator.get_distance(alignment)
constructor=DistanceTreeConstructor()
tree=constructor.upgma(dm)
#Phylo.write(tree,"phylogenetic_tree.nwk", "newick")
Phylo.draw(tree)
plt.show()

# %%
from Bio import Phylo, AlignIO
from Bio.Phylo.TreeConstruction import DistanceCalculator, DistanceTreeConstructor
import matplotlib.pyplot as plt

# %%
alignment=AlignIO.read("out.aln","clustal")
calculator=DistanceCalculator()
dm=calculator.get_distance(alignment)
constructor=DistanceTreeConstructor()
tree=constructor.upgma(dm)
Phylo.write(tree,"tree.nwk","newick")
Phylo.draw(tree)
plt.show()
